# %%
# Importing packages
import pandas as pd

# %%
# Read the UH_2023_TRAIN.txt dataset
TRAIN = pd.read_table('UH_2023_TRAIN.txt', delimiter = '|')
TRAIN.head()
# Out:
# C:\Users\cfrag\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
#
# C:\Users\cfrag\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: read_table is deprecated, use read_csv instead.
#   """
# C:\Users\cfrag\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: read_table is deprecated, use read_csv instead.
#           validTimeUtc  precip1Hour  precip6Hour  precip24Hour  precip2Day  \
# 0  2015-06-29 16:20:00          0.0          0.0           0.0         NaN
# 1  2015-06-29 17:20:00          0.0          0.0           0.0         NaN
# 2  2015-06-29 18:20:00          0.0          0.0           0.0         NaN
# 3  2015-06-29 19:20:00          0.0          0.0           0.0         NaN
# 4  2015-06-29 20:20:00          0.0          0.0           0.0         NaN
#
#    precip3Day  precip7Day  precipMtd  precipYtd  pressureChange  ...  \
# ...

# %%
# Read the DATOS_ETO.txt dataset
ETO = pd.read_table('DATOS_ETO.txt', delimiter = '|')
ETO.head()
# Out:
# C:\Users\cfrag\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.
#        date  DewpointLocalAfternoonAvg  DewpointLocalAfternoonMax  \
# 0  20150629                      285.9                      285.9
# 1  20150630                      283.0                      283.6
# 2  20150701                      286.1                      286.5
# 3  20150702                      288.9                      289.4
# 4  20150703                      289.1                      290.4
#
#    DewpointLocalAfternoonMin  DewpointLocalDayAvg  DewpointLocalDayMax  \
# 0                      285.9                286.0                287.0
# 1                      282.5                284.3                286.5
# 2                      285.5                285.8                288.0
# 3                      287.9                288.3                291.8
# 4                      288.5                290.5                293.0
#
# ...

# %%
# Read the DATOS_METEO.txt dataset
METEO = pd.read_table('DATOS_METEO.txt', delimiter = '|')
METEO.head()
